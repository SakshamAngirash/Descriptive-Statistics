# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.stats import norm 

#Generate 1000 normal random integers with specified mean and std
draw=norm.ppf(np.random.random(100000),loc=1000,scale=200).astype(int)
sns.distplot(draw)
# Out:
# C:\Users\Saksham\AppData\Local\Temp\ipykernel_19488\1944811307.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(draw)
# <Axes: ylabel='Density'>

# %%
z=[]
for i in draw: 
    z.append((i-1000)/200)

# %%
a=np.array(z)

# %%
print(a.mean())
print (np.round(a.mean()))
# Out:
# 3.22999999999999e-05
# 0.0

# %%
print(a.std())
print(np.round(a.std()))
# Out:
# 0.999355930565637
# 1.0

# %% [markdown]
# ### Calculating Z Score
# - Imagine a group of students who took a test , rohit scored 700 . the avg score was 500 and std was 120 . assuming normal dist how well rohit performed compared to his peers

# %%
# step 1 calculate the Z-Score
z=(700-500)/120
print(z)
# Out:
# 1.6666666666666667

# %%
# step 2 - Look up the z table 
# ztable.com : 1.66 : 
a=0.9515

# %%
# step 3 - Multiply by 100
a*100
# Out:
# 95.15
